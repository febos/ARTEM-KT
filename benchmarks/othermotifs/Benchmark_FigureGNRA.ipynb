# %%
#Counter({'dssr': 1934, 'artem,dssr': 963, 'artem': 164, 'artem,dssr,rna_motif': 153, 
#'rna_motif': 123, 'dssr,rna_motif': 85, 'artem,rna_motif': 24})

cats = ['ARTEM', 'DSSR (U-turns)','rna_motif (GNRA_TETRALOOP)']

from upsetplot import from_memberships
example = from_memberships(
    [[cats[1],],
     [cats[1],cats[0]],
     [cats[0]],
     [cats[1],cats[0],cats[2]],
     [cats[2]],
     [cats[1],cats[2]],
     [cats[0],cats[2]],
     ],
     data=[1934,963,164,153,123,85,24]
)

# %%
from upsetplot import plot

from matplotlib import pyplot as plt
plt.suptitle("ARTEM-DSSR benchmark (2394 PDB entries)")
plot(example, show_counts="{:,}") 
plt.savefig("gnrabench.svg")
plt.show()
